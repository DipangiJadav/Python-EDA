# %% [markdown]
# <a href="https://colab.research.google.com/github/DipangiJadav/Python-EDA/blob/main/Hotel_Booking_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Name: Hotel Booking Analysis
#
# #### Project Type: EDA
# #### Submitted By: Dipangi Jadav

# %% [markdown]
# # Project Summary
#
# This project aims to conduct an exploratory data analysis (EDA) on a dataset of hotel bookings to gain insights on booking patterns and customer behaviour. The analysis will focus on dentifying patterns in bookings and cancellations, customer demographics and preferences, and the effectiveness of different distribution channels.
#
# Data Source: https://www.kaggle.com/datasets/mojtaba142/hotel-booking

# %% [markdown]
# # Problem Statement
#
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.

# %% [markdown]
# # Business Objective
#
# The business objectives that this project tries to achieve are
#
# *   To gain a comprehensive understanding of booking patterns and customer behavior.
# *   Understand which amenities and services are most popular among guests.
# *   Determine key drivers of occupancy, revenue, and customer satisfaction.
# *   Form strategies for increasing occupancy, revenue and customer satisfaction.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('/content/sample_data/Hotel Bookings.csv')

# %% [markdown]
# ## Exploratory Data Analysis and Data Cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# convert the reservation_status_date to date-time anf update to df dataset
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include = 'object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# what are the unique values object column have

for col in df.describe(include = 'object').columns:
  print(col)
  print(df[col].unique())
  print('-'*40)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ----------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ----------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ----------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
# Creating copy of DataSet
df1 = df.copy()

# %%
# column name list
print(list(df1.columns))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# Checking for duplicate rows; where True means duplicated rows
df1.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %% [markdown]
# we have 31994 duplicate rows in our data which we have to drop it from our data.

# %%
# Dropping the duplicate rows
df1 = df1.drop_duplicates()

# %%
df1.shape
# Out:
# (87396, 32)

# %%
df1.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Let's visualizing the null value with heat map

plt.figure(figsize=(23,10))
sns.heatmap(df1.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.xlabel("Column Name")
plt.title("Missing Values in Columns")
# Out:
# Text(0.5, 1.0, 'Missing Values in Columns')

# %% [markdown]
# We have Null values in columns like company,agent,country,children.
# - For company and agent we will fill the missing vlaues with 0.
# - For country we will fill missing values with 'Others'(assuming while collecting data country was not found so user selected 'other' option)
# - As the count of missing values in children column is only 4, so we can replace with 0 considering no childrens.

# %%
# Replacing null values with 0
null_columns = ['children','agent','company']
for col in null_columns:
  df1[col].fillna(0,inplace=True)

# %%
# Replacing NA with 'others'
df1['country'].fillna('others',inplace=True)

# %%
df1.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# checking the shape of dataset whose combining values of adults,babies and children column is 0
df1[df1['adults']+df1['babies']+df1['children']==0].shape
# Out:
# (166, 32)

# %%
# Dropping the rows where combining values of adults, babies and children is 0 because it means no booking were made.
df1.drop(df1[df1['adults']+df1['babies']+df1['children']==0].index,inplace=True)

# %%
df1[df1['adults']+df1['babies']+df1['children']==0].shape
# Out:
# (0, 32)

# %%
# Let's add some new columns:
df1['total_persons'] = df1['adults'] + df1['babies'] + df1['children']
df1['total_stays'] = df1['stays_in_weekend_nights'] + df1['stays_in_week_nights']

# %%
df1['total_persons'].dtype
# Out:
# dtype('float64')

# %%
df1['total_persons'] = df1['total_persons'].astype(int)

# %%
df1['total_persons']
# Out:
# 0         2
# 1         2
# 2         1
# 3         1
# 4         2
#          ..
# 119385    2
# 119386    3
# 119387    2
# 119388    2
# 119389    2
# Name: total_persons, Length: 87230, dtype: int64

# %%
df1['total_stays']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: total_stays, Length: 87230, dtype: int64

# %%
df1.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87230.000000  87230.000000       87230.000000
# mean       0.275238     79.971019        2016.210352
# std        0.446637     86.058683           0.686064
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87230.000000               87230.000000
# mean                  26.835091                  15.815832
# std                   13.669216                   8.835545
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# Findings:
# - we can see there are outlier in childere and babies as max values shows 10 and now a days it is hardly find that anyone can have 10 children and so many 0s are there in that columns.
# - there is a outliers in ADR column which is useful for our analysis like min is -6 and max is 5400 so it is big outlier for our analysis.

# %%
df1['adr'].plot(kind = 'box')
#df['children'].plot(kind = 'box')
#df['babies'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df1['children'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df1['babies'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
# Remove the outlier from adr
df1 = df1[df1['adr'] < 5000]

# %%
df1.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87229.000000  87229.000000       87229.000000
# mean       0.275230     79.971535        2016.210354
# std        0.446632     86.059042           0.686067
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87229.000000               87229.000000
# mean                  26.835250                  15.815726
# std                   13.669214                   8.835541
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %%
df1.shape
# Out:
# (87229, 34)

# %% [markdown]
# ## Data Analysis and Visualization

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Which type of hotel is mostly prefered by the guests??

# %%
# Visualizing by pie chart
df1['hotel'].value_counts().plot.pie(shadow=True, figsize=(10,8), fontsize=16, autopct='%1.1f%%', explode=[0.05, 0.05])
plt.title('Most Prefered Hotel by Guests')
# Out:
# Text(0.5, 1.0, 'Most Prefered Hotel by Guests')

# %% [markdown]
# City Hotel is most prefered by guest thus it has highest bookings.

# %% [markdown]
# ## Which agent made the highest bookings???

# %%
# Highest number of bookings

highest_bookings = df1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)
highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 0      0.0          12141
# 14    14.0           3342
# 7      7.0           3294
# ..     ...            ...
# 194  267.0              1
# 65    73.0              1
# 251  352.0              1
# 193  265.0              1
# 300  446.0              1
#
# [334 rows x 2 columns]

# %%
# As agent 0 was NAN value and we replaced it with 0 which indicated no bookings so we are dropping it
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index, inplace=True)

# Top 10 bookings made by agent
top_ten_bookings = highest_bookings[:10]
top_ten_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28721
# 174  240.0          13028
# 14    14.0           3342
# 7      7.0           3294
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1493
# 8      8.0           1383
# 1      1.0           1228
# 6      6.0           1117

# %%
# Let's visualize top 10 bookings:
plt.figure(figsize=(18,8))
sns.barplot(x=top_ten_bookings['agent'], y=top_ten_bookings['Most_Bookings'], order = top_ten_bookings['agent'])
#sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Agent_No')
plt.ylabel('Number of Bookings')
plt.title('Highest Bookings Made by Agents')
# Out:
# Text(0.5, 1.0, 'Highest Bookings Made by Agents')

# %% [markdown]
# Agent_Id 9.0 has made the highest number of bookings

# %% [markdown]
# ## What is the percentage of Booking cancellation???

# %%
df1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Percentage of Booking Cancellation and Non Cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of Booking Cancellation and Non Cancellation')

# %% [markdown]
# Here, 0 means not canceled and 1 means canceled
# 27.5% of the bookings were cancelled.

# %% [markdown]
# ## What is the percentage of repeated guests???

# %%
df1['is_repeated_guest'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)
plt.title("Percentage of Repeated Guests")
# Out:
# Text(0.5, 1.0, 'Percentage of Repeated Guests')

# %% [markdown]
# Here, repeated guests are very few which is only 3.9%
# in order to retained the guests, management should take feedbacks from the guests and try to improve the services.
# Also they should offer some discounts so guests can leverage more services offered by them.

# %% [markdown]
# ## What is the percentage of distribution of Customer type???

# %%
df1['customer_type'].value_counts().plot.pie(explode=[0.05]*4, autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=16)
plt.title("Distribution of Customer Type")
labels=df1['customer_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# 1 Contract: when the booking has an allotment or other type of contract associated to it
#
# 2 Group: when the booking is associated to a group
#
# 3 Transient: when the booking is not part of a group or contract, and is not associated to other transient booking
#
# 4 Transient-party: when the booking is transient, but is associated to at least other transient booking
#
# Here, Transient customer type is highest customer type which is 82.4% and bookings associated by Group is very low which is 0.6%

# %% [markdown]
# ## What is the percentage distribution of required car parking spaces??

# %%
df1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=16)
plt.title("Distribution of Required Car Parking Spaces")
labels=df1['required_car_parking_spaces'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# Here, most of the guest did not required the parking space. Only few which is 8.3% guests required 1 parking space.

# %% [markdown]
# ## What is the percentage of booking changes made by the customer?

# %%
booking_changes_customer = df1['booking_changes'].value_counts().reset_index().rename(columns={'index': "number_of_booking_changes",'booking_changes':'Counts'})


plt.figure(figsize=(15,8))
sns.barplot(x=booking_changes_customer['number_of_booking_changes'], y=booking_changes_customer['Counts']*100/df1.shape[0])
#sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Number of Booking changes')
plt.ylabel('Percentage of changes')
plt.title('Percentage of Booking Changes made by Customers')
# Out:
# Text(0.5, 1.0, 'Percentage of Booking Changes made by Customers')

# %% [markdown]
# Here 0 means o change made in booking, 1 means 1 change made in booking, 2 mens 2 change made in booking.
# So, 82% of booking were not changed by customers.

# %% [markdown]
# ## What is percentage distribution of Deposite type???

# %%
df1['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=True,figsize=(15,8),fontsize=16)
plt.title("Percentage Distribution of Deposit Type")
labels=df1['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# Here,98.7% guests prefer no deposite type.

# %% [markdown]
# ## Which type of food is mostly preferred by the guests?

# %%
#df1['meal'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], autopct='%1.1f%%', shadow=True, figsize=(18,12),fontsize=20)
plt.figure(figsize=(12,8))
sns.countplot(x=df1['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type by Guests")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type by Guests')

# %% [markdown]
# Types of meal in hotels:
#
# BB - (Bed and Breakfast)
# HB- (Half Board)
# FB- (Full Board)
# SC- (Self Catering)
#
# so here , Bed and Breakfast meal type is mostly prefered by guests. and Half board and self catering equaly prefered by some.

# %% [markdown]
# ## From which country the most guests are coming?

# %%
# Counting the guests from various countries.
country_df = df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by  plotting the graph
plt.figure(figsize=(16,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# Abbreevations for countries-
#
# PRT- Portugal
# GBR- United Kingdom
# FRA- France
# ESP- Spain
# DEU - Germany
# ITA -Itlay
# IRL - Ireland
# BEL -Belgium
# BRA -Brazil
# NLD-Netherlands
#
# Here, Most of the guests are coming from Portugal.

# %% [markdown]
# ## Which is the most preferred room type by the customers???

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=df1['assigned_room_type'],order=df1['assigned_room_type'].value_counts().index)
plt.xlabel('Room Type')
plt.ylabel('Count of Room Type')
plt.title("Most preferred Room type by Guests")
# Out:
# Text(0.5, 1.0, 'Most preferred Room type by Guests')

# %% [markdown]
# Here, room type A is most preferred by guests.

# %% [markdown]
# ## In which month most of the bookings happened???

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=df1.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')

bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7488
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
# set plot size
plt.figure(figsize=(20,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings on each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# Here, July and August months had the most bookings.

# %% [markdown]
# ## Which distribution channel is mostly used for hotel bookings ???

# %%
#Creating labels
labels=df1['distribution_channel'].value_counts().index.tolist()

# creating new df of distribution channel
distribution_channel_df=df1['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})

#adding percentage columns to the distribution_channel_df
distribution_channel_df['percentage']=round(distribution_channel_df['count']*100/df1.shape[0],1)

#Creating list of percentage
sizes=distribution_channel_df['percentage'].values.tolist()

#plotting the piw chart
df1['distribution_channel'].value_counts().plot.pie(explode=[0.05, 0.05,0.05,0.05,0.05], shadow=False, figsize=(15,8),fontsize=10,labels=None)

# setting legends with the percentage values
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
plt.title(' Mostly Used Distribution Channel for Hotel Bookings ')
# Out:
# Text(0.5, 1.0, ' Mostly Used Distribution Channel for Hotel Bookings ')

# %% [markdown]
# Here, TA/TO is mostly  used for hotel bookings.

# %% [markdown]
# ## which years has the highest bookings???

# %%
plt.figure(figsize=(12,8))

#  plot with countplot
sns.countplot(x=df1['arrival_date_year'],hue=df1['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# Here, we can see that 2016 had the highest bookings and 2015 had lowest like less than 7000 bookings.
# Overall, City hotel had the most of the bookings.

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %% [markdown]
# ## Which hotel type has the highest ADR??

# %%
# Group by hotel

group_by_hotel = df1.groupby('hotel')

# %%
highest_adr = group_by_hotel['adr'].mean().reset_index()
plt.figure(figsize=(10,8))
# set labels
plt.xlabel('Hotel Type')
plt.ylabel('ADR')
plt.title('Avg ADR of Each Hotel type')
# Plot the graph
sns.barplot(x=highest_adr['hotel'], y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'Avg ADR of Each Hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# Here, city hotel has the highest ADR. That means city hotels are generating more revenues than the resort hotel.

# %% [markdown]
# ## Which hotel type has more lead time ???

# %%
#group by hotel and taking mean of lead time
avg_lead_time=group_by_hotel['lead_time'].mean().reset_index()

#set plot size
plt.figure(figsize=(10,8))

# plot the bar plot
sns.barplot(x=avg_lead_time['hotel'],y=avg_lead_time['lead_time'])
# set lables
plt.xlabel('Hotel type')
plt.ylabel('Average Lead time')
plt.title("Average Lead Time for each Hotel type")
# Out:
# Text(0.5, 1.0, 'Average Lead Time for each Hotel type')

# %% [markdown]
# Resort hotels has slightly high avg lead time. That means customers plan their trips very early.

# %% [markdown]
# ## Which hotel type has highest number of bookings cancellation???

# %%
# booking canceled=1
# booking not canceled= 0

# creating new DataFrame where bookings are cancelled.
canceled_df=df1[df1['is_canceled']==1]

# Grouping by hotel
canceled_df=canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# adding 'total booking column for calculating the percentage.
canceled_df['total_booikngs']=df1.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)
canceled_df

#plotting the barchat
plt.figure(figsize=(10,8))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['no_of_cancelled_bookings']*100/canceled_df['total_booikngs'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('Percentage(%)')
plt.title("Percentage of booking cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of booking cancellation')

# %% [markdown]
# Here, City hotel has highest number of booking cancellation.

# %% [markdown]
# ## Which hotel has longer wait time???

# %%
#groupping by hoetl and takin mean of days in waiting list
waiting_time_df=df1.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
# waiting_time_df

#set the plot size
plt.figure(figsize=(10,8))

# plot barchart
sns.barplot(x=waiting_time_df['hotel'],y=waiting_time_df['days_in_waiting_list'])

#set labels
plt.xlabel('Hotel type')
plt.ylabel('waiting time')
plt.title("Waiting time for each hotel type")
# Out:
# Text(0.5, 1.0, 'Waiting time for each hotel type')

# %% [markdown]
# Here, city hotel has highest wait time means it is more busier than resort hotel.

# %% [markdown]
# ## Which hotel has the most repeated guests???

# %%
# repeated guest=1
#not repeated guest=0
#groupby hotel
repeated_guests_df=df1[df1['is_repeated_guest']==1].groupby('hotel').size().reset_index().rename(columns={0:'number_of_repated_guests'})

#set plot size adn plot barplot
plt.figure(figsize=(10,8))
sns.barplot(x=repeated_guests_df['hotel'],y=repeated_guests_df['number_of_repated_guests'])

# set labels
plt.xlabel('Hotel type')
plt.ylabel('count of repeated guests')
plt.title("Most repeated guests for each hotel")
# Out:
# Text(0.5, 1.0, 'Most repeated guests for each hotel')

# %% [markdown]
# Resort Hotel has slightly more repeated guests than the City Hotels. It is almost similar for both hotels.

# %% [markdown]
# ## ADR Across the different months

# %%
#groupby
bookings_by_months_df=df1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()
#create month list
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# it will take the order of the month list in the df along with values
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
#sortting
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.269875
# 9             January  Resort Hotel   49.181693
# 6            February    City Hotel   89.266427
# 7            February  Resort Hotel   54.102809
# 15              March  Resort Hotel   57.590889
# 14              March    City Hotel   94.096062
# 0               April    City Hotel  117.314134
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  128.055724
# 13               June  Resort Hotel  112.380859
# 12               June    City Hotel  123.996416
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.318314
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  125.148662
# 22          September    City Hotel  118.764693
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.585401
# ...

# %%
# set plot size and plot the line
plt.figure(figsize=(15,8))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# set lables
plt.title('ADR Across Each Month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# For Resrot hotel is ADR is high in the months June,July,August as compared to City Hotels. May be Customers wants to spend their Summer vaccation in Resorts Hotels.
#
# The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December as the avrage daily rate in this month is very low.

# %% [markdown]
# ## Which distribution channel contributed more to adr in order to increase the the income?

# %%
# group by distribution channel and hotel
distribution_channel_df=df1.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# set plot size and plot barchart
plt.figure(figsize=(16,8))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# - Corporate: These are corporate hotel booing companies which makes bookings
# possible.
# - GDS: A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# -Direct: means that bookings are directly made with the respective hotels
# -TA/TO: means that booings are made through travel agents or travel operators.
# -Undefined: Bookings are undefined. may be customers made their bookings on arrival.
#
# From the plot is clear that,
# 'Direct' and 'TA/TO' has almost equally contributed in adr in both type of hotels i.e. 'City Hotel' and 'Resort Hotel'.
# GDS has highly contributed in adr in 'City Hotel' type.
# GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# ## Which distribution channel has the higest cancellation rate?

# %%
canceled_df=df1[df1['is_canceled']==1] # 1= canceled

#group by distribution channel
canceled_df=canceled_df.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})
# canceled_df['Percentage']=canceled_df['Counts']*100/df1[df1['is_canceled']==1][0]
canceled_df

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x='distribution_channel',y='Counts',hue="hotel",data=canceled_df)

# set labels
plt.xlabel('Distribution channel')
plt.ylabel('counts')
plt.title('Cancellation Rate Vs Distribution channel')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Distribution channel')

# %% [markdown]
# In "TA/TO", City hotels has the high cancellation rate compared to resort
# hotels.
#
# In "direct" both the hotels has almost same cancellation rate.

# %% [markdown]
# ## Which Market Segment has the higest cancellation rate?

# %%
market_segment_df=df1[df1['is_canceled']==1]   # canceled=1
market_segment_df
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by

market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      54
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     263
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     887
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1256
# 10  Offline TA/TO  Resort Hotel     800
# 11      Online TA    City Hotel   12615
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
#set plotsizde and plot barchart
plt.figure(figsize=(15,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)

# set labels
plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs market_segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs market_segment')

# %% [markdown]
# Here, 'Online T/A' has the highest cancellation in both type of cities
# In order to reduce the booking cancellations hotels need to set the refundable/ no refundable and deposit policies policies

# %% [markdown]
# ## Does the guests alloted with the same room type which was reserved by them?

# %%
# Define a function for the reserved room type is same  or not as  assigned room type
def same_room_allotment(x):
  '''function to check whether the reserved room
  type is same  or not as  assigned room type'''

  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

# %%
# create new column to df1
df1['Same_room_alloted_or_not']=df1.apply(lambda x: same_room_allotment(x),axis=1)

#groupby is canceled
grp_by_canceled_df=df1.groupby('is_canceled')

# create DF and calculate  percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:"percentage"})
DF

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x=DF.index,y=DF['percentage'])

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','canceled'])
# Out:
# ([<matplotlib.axis.XTick at 0x7d163fd26b90>,
# ...
#  [Text(0, 0, 'Not canceled'), Text(1, 0, 'canceled')])

# %% [markdown]
# Here, Its is clear that there is no much(2.5%) effect on cancellation of the bookings even if the guests are not assigned with rooms which they reserved during booking.

# %% [markdown]
# ## ADR across different market segment

# %%
Grupby=df1.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()   # group by

# set plot size and plto barchart
plt.figure(figsize=(18,6))
sns.barplot(x='market_segment',y='adr',hue='hotel',data=Grupby.sort_values(by='adr',ascending=False))
plt.title('Adr across market segment')
# Out:
# Text(0.5, 1.0, 'Adr across market segment')

# %% [markdown]
# Here, 'Direct' and 'Online TA' are contributing the most in both types of hotels.
# Aviation segment should focus on increasing the bookings of 'City Hotel'

# %% [markdown]
# ## What is the Optimal stay length in both types of hotels ?

# %%
stay = df1.groupby(['total_stays', 'hotel']).agg('count').reset_index()   # group by total stay and hotel
stay = stay.iloc[:, :3]                                                   # take 1st 3 columns
stay = stay.rename(columns={'is_canceled':'Number of stays'})    # rename the columns

# %%
# set plot size and plot barchart
plt.figure(figsize=(18,9))
sns.barplot(x='total_stays',y='Number of stays',hue='hotel',data=stay)

#set labels
plt.title('Optimal Stay Length in Both hotel types')
plt.ylabel('count of stays')
plt.xlabel('total_stay(days)')
# Out:
# Text(0.5, 0, 'total_stay(days)')

# %% [markdown]
# Here, Optimal stay in both the type hotel is less than 7 days.

# %% [markdown]
# ## Relationship between ADR and total stay

# %%
# Groupby adr,total,stay,hotel,
adr_vs_stay = df1.groupby(['total_stays', 'adr','hotel']).agg('count').reset_index()
adr_vs_stay = adr_vs_stay.iloc[:, :3]
adr_vs_stay = adr_vs_stay.rename(columns={'is_canceled':'Number of stays'})
adr_vs_stay=adr_vs_stay[:18000]
adr_vs_stay
# Out:
#        total_stays     adr         hotel
# 0                0    0.00    City Hotel
# 1                0    0.00  Resort Hotel
# 2                1    0.00    City Hotel
# 3                1    0.00  Resort Hotel
# 4                1    1.00    City Hotel
# ...            ...     ...           ...
# 17995            7  212.10  Resort Hotel
# 17996            7  212.14  Resort Hotel
# 17997            7  212.29    City Hotel
# 17998            7  212.29  Resort Hotel
# 17999            7  212.40    City Hotel
#
# [18000 rows x 3 columns]

# %%
#plot line chart
plt.figure(figsize=(12,8))
sns.lineplot(x='total_stays',y='adr',data=adr_vs_stay)
plt.title('Relationship between adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between adr and total stay')

# %% [markdown]
# Here, As the total stay increases the adr also increases.

# %% [markdown]
# ## Correlation of the columns

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df1.corr(),annot=True)
plt.title('Correlation of Columns')
# Out:
# <ipython-input-74-44c2b116484c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(),annot=True)
# Text(0.5, 1.0, 'Correlation of Columns')

# %% [markdown]
# 1) is_canceled and same_room_alloted_or_not are negatively corelated. That means customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.
#
# 2) lead_time and total_stay is positively corelated.That means more is the stay of cutsomer more will be the lead time.
#
# 3)adults,childrens and babies are corelated to each other. That means more the people more will be adr.
#
# 4) is_repeated guest and previous bookings not canceled has strong corelation. may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## Relationship between the repeated guests and previous bookings not canceled???

# %%
repeated_guests_df=df1[df1['is_repeated_guest']==1]
repeated_guests_df_1=df1[df1['is_repeated_guest']==0]

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=df1['is_repeated_guest'],y= df1['previous_bookings_not_canceled'])
plt.xticks([0,1],['Not_repeated_guests','repeated_guests'],fontsize=15)
plt.title('Relationship Between repeated guests and previous bookings not cancelled')
plt.show()

# %% [markdown]
# Not Repeated guests are more likely to cancel their bookings.

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x=df1['total_stays'],y=df1['adr'])
plt.title('Relationship between  adr and total stay')
# Out:
# Text(0.5, 1.0, 'Relationship between  adr and total stay')

# %% [markdown]
# From above scatter we can say that as the stay increases adr is decreasing. Thus for longer stays customer can get good adr.

# %% [markdown]
# ## ADR relationship with total number of people

# %%
plt.figure(figsize=(18,8))
df2=df1[df1['total_persons'] < 6]

sns.boxplot(x=df2['total_persons'],y=df2['adr'])

# set lables
plt.title('ADR v/s Total Number of persons')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of persons')

# %% [markdown]
# As the total number of people increases adr also increases.
# Thus adr and total people are directly proportional to each other.

# %% [markdown]
# # Findings:
#
#
# *   The guests showed a preference for City hotels, making it the busiest type of hotel so stakeholders can offers discounts on Resort hotels to attract customers.
#
# *   Around 27.52% of bookings are cancelled so Hotel can offer layality discount if guests don't cnacel their booking.
#
# *   Only 3.9% of guests revisited the hotels, indicating a low retention rate.
#
# *   Over 82% of bookings had 0 changes made, while around 10% had single changes made.
#
#
# *   The majority of customers (91.6%) did not require car parking spaces.
#
# *   About 79.1% of bookings were made through travel agents/tour operators.
#
# *  Bed & Breakfast (BB) was the most preferred meal type among guests.
#
# *   Maximum number of guests were from Portugal.
#
# *  Most bookings for City and Resort hotels were made in 2016.
#
# *   City hotels generated more revenue than Resort hotels, with higher average ADR.
#
#
# *   City hotels had a higher booking cancellation rate of almost 30%.
#
# *   Resort hotels had a higher average lead time.
#
# *   Number of repeated guests is low that indicates that there is something they don't like about Hotel and that needs to be fixed to increase number of repeated guests.
#
# *   Waiting time was higher for City hotels compared to Resort hotels, indicating City hotels were busier.
#
#
# *  Resort hotels had the highest number of repeated guests.
#
# *   Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week so Hotel need to take some actions to improve their services.
#
# *   About 19% of people did not cancel their bookings despite not getting the reserved room, while only 2.5% cancelled their booking.

# %% [markdown]
# # Solutions to Business Objectives
#
#
#
# *  The Booking patterns consistently peak in July and August, increase staffing and inventory during these months to accommodate the increased demand.
#
# *  Optimize pricing and availability of room types based on customer preferences. Since room type A is the most preferred, ensure that it is available during peak booking months and adjust pricing accordingly.
#
# *  Increase customer satisfaction by improving the online booking process and customer support.
#
# *  Since breakfast in bed is the most popular meal,consider offering it more often or as a package deal to increase revenue and customer satisfaction.
#
# *  Negative correlation between ADR and stay duration suggests that customers staying for shorter periods generate more ADR. This information can inform the company to focus on attracting more of these customers to increase revenue.
#
# *  The information on the average stay duration being relatively higher for the months June to September can help the hotel management to better allocate resources to meet customer needs during these periods.
#
# *  To reduce the cancellation rates, the management could encourage customers who are making a deposit by providing additional offers and reduced rates.
# *  The hotel should direct its marketing efforts towards online mediums to capture more bookings.
